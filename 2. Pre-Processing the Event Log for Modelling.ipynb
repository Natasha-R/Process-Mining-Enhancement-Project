# %% [markdown]
# ## Importing the data

# %%
import pandas as pd
import pm4py
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("event_logs/filtered_event_log_complete_clear_invoice.csv", sep=";", parse_dates=["event_timestamp"])

# %% [markdown]
# The aim of this project is to use case attributes of the purchase orders to create a model that attempts to predict the throughput time of each purchase order. To achieve this, an appropriate dataset must be created from the filtered event log.

# %% [markdown]
# ## Creating a table of case attributes for each line item

# %% [markdown]
# The PR_NPR, product types, vendor and value are generally consistent across all of the events related to a particular line item.
# The associated resources and occurrence of different events in each line items trace will need to be added after.

# %%
data.groupby("case_id").nunique().mean()
# Out:
# case_PO_id               1.000000
# event_id                 5.652626
# event_name               5.517371
# event_timestamp          5.607721
# event_resource           5.432430
# event_value_EUR          1.001507
# case_vendor              1.000000
# case_PR_NPR              0.990687
# case_product_type        0.990687
# case_product_specific    0.990687
# dtype: float64

# %% [markdown]
# Starting with the beginning event time stamp and case attributes:

# %%
start_case = data.groupby("case_id").nth(0)[["event_timestamp", "event_value_EUR", "case_vendor", "case_PR_NPR", "case_product_type", "case_product_specific"]]
start_case.rename(columns={"event_timestamp":"start_timestamp"})
start_case.head()
# Out:
#                            event_timestamp  event_value_EUR    case_vendor  \
# case_id
# 4507000266_00010 2018-02-01 08:53:00+00:00            134.0  vendorID_0103
# 4507000268_00010 2018-02-01 08:56:00+00:00            212.0  vendorID_0105
# 4507000268_00020 2018-02-01 08:56:00+00:00            389.0  vendorID_0105
# 4507000272_00010 2018-02-01 09:06:00+00:00            266.0  vendorID_0137
# 4507000272_00040 2018-02-01 09:06:00+00:00           1272.0  vendorID_0137
#
#                  case_PR_NPR case_product_type case_product_specific
# case_id
# 4507000266_00010          PR         Packaging                Labels
# 4507000268_00010          PR         Packaging                Labels
# 4507000268_00020          PR         Packaging                Labels
# 4507000272_00010         NPR             Sales   Products for Resale
# 4507000272_00040         NPR             Sales   Products for Resale

# %% [markdown]
# Adding the end event timestamp:

# %%
end_case = data.groupby("case_id").nth(-1)["event_timestamp"]
end_case = end_case.rename("end_timestamp")

# %% [markdown]
# Calculating the case total throughput for each line item:

# %%
li_data = pd.merge(start_case, end_case, left_index=True, right_index=True, how="outer")
li_data = li_data.rename(columns={"event_timestamp":"start_timestamp"})

# %%
li_data["throughput"] = li_data["end_timestamp"] - li_data["start_timestamp"]

# %%
li_data.head()
# Out:
#                            start_timestamp  event_value_EUR    case_vendor  \
# case_id
# 4507000266_00010 2018-02-01 08:53:00+00:00            134.0  vendorID_0103
# 4507000268_00010 2018-02-01 08:56:00+00:00            212.0  vendorID_0105
# 4507000268_00020 2018-02-01 08:56:00+00:00            389.0  vendorID_0105
# 4507000272_00010 2018-02-01 09:06:00+00:00            266.0  vendorID_0137
# 4507000272_00040 2018-02-01 09:06:00+00:00           1272.0  vendorID_0137
#
#                  case_PR_NPR case_product_type case_product_specific  \
# case_id
# 4507000266_00010          PR         Packaging                Labels
# 4507000268_00010          PR         Packaging                Labels
# 4507000268_00020          PR         Packaging                Labels
# 4507000272_00010         NPR             Sales   Products for Resale
# 4507000272_00040         NPR             Sales   Products for Resale
#
#                              end_timestamp        throughput
# case_id
# 4507000266_00010 2018-04-26 09:14:00+00:00  84 days 00:21:00
# 4507000268_00010 2018-09-05 12:10:00+00:00 216 days 03:14:00
# 4507000268_00020 2018-09-05 12:10:00+00:00 216 days 03:14:00
# 4507000272_00010 2018-09-05 12:12:00+00:00 216 days 03:06:00
# 4507000272_00040 2018-09-05 12:12:00+00:00 216 days 03:06:00

# %% [markdown]
# Some items have no product types included:

# %%
li_data[li_data["case_PR_NPR"].isna()].head(5)
# Out:
#                            start_timestamp  event_value_EUR    case_vendor  \
# case_id
# 4507002823_00030 2018-01-15 08:40:00+00:00            208.0  vendorID_0103
# 4507002823_00050 2018-01-15 08:40:00+00:00            338.0  vendorID_0103
# 4507002823_00060 2018-01-15 08:40:00+00:00            507.0  vendorID_0103
# 4507002823_00070 2018-01-15 08:40:00+00:00            338.0  vendorID_0103
# 4507002823_00080 2018-01-15 08:40:00+00:00            338.0  vendorID_0103
#
#                  case_PR_NPR case_product_type case_product_specific  \
# case_id
# 4507002823_00030         NaN               NaN                   NaN
# 4507002823_00050         NaN               NaN                   NaN
# 4507002823_00060         NaN               NaN                   NaN
# 4507002823_00070         NaN               NaN                   NaN
# 4507002823_00080         NaN               NaN                   NaN
#
#                              end_timestamp        throughput
# case_id
# 4507002823_00030 2018-04-26 09:14:00+00:00 101 days 00:34:00
# 4507002823_00050 2018-04-26 09:14:00+00:00 101 days 00:34:00
# 4507002823_00060 2018-04-26 09:14:00+00:00 101 days 00:34:00
# 4507002823_00070 2018-04-26 09:14:00+00:00 101 days 00:34:00
# 4507002823_00080 2018-04-26 09:14:00+00:00 101 days 00:34:00

# %%
li_data = li_data.dropna(how="any")

# %% [markdown]
# ### Feature engineering other relevant case attributes

# %% [markdown]
# Finding rework rate per case:

# %%
rework_activities = ['Change Price', 'Change Quantity', 'Change Delivery Indicator',
                     'Vendor creates debit memo', 'Cancel Invoice Receipt','Change Storage Location', 
                     'Change Currency', 'Reactivate Purchase Order Item', 'Change Approval for Purchase Order', 
                     'Cancel Goods Receipt','Cancel Subsequent Invoice', 'Update Order Confirmation', 
                     'Record Subsequent Invoice', 'Change payment term']

# %%
li_data = pd.merge(li_data, data[data["event_name"].isin(rework_activities)].groupby("case_id").count()["event_name"].rename("rework_activities"), 
         how="left", left_index=True, right_index=True)
li_data["rework_activities"] = li_data["rework_activities"].fillna(0)

# %% [markdown]
# Was a payment block used? ("Remove payment block" occurred):

# %%
cases_w_pb = pd.DataFrame(data[data["event_name"]=="Remove Payment Block"]["case_id"].unique())
cases_w_pb["payment_block"] = True
cases_w_pb = cases_w_pb.set_index(0)

# %%
li_data = pd.merge(li_data, cases_w_pb, how="left", left_index=True, right_index=True)
li_data["payment_block"] = li_data["payment_block"].fillna(False)

# %% [markdown]
# Automation rate per case:

# %%
data["automation"] = data["event_resource"].str[0]
data["automation"] = data["automation"].replace({"u": False, 
                                                 "b": True, 
                                                 "N" : np.nan})

# %%
li_data = pd.merge(li_data, data.dropna().groupby("case_id")["automation"].mean()*100, how="left", left_index=True, right_index=True)

# %% [markdown]
# Average daily workload (number of cases being worked on) for the duration of the case, per vendor:

# %%
data["event_date"] = data["event_timestamp"].dt.date

# %% [raw]
# all_cases = list(li_data.index)
# all_workload = list()
# for case in all_cases:
#     vendor = data[data["case_id"] == case]["case_vendor"].iloc[0]
#     only_vendor_data = data[data["case_vendor"] == vendor]
#     between_dates = only_vendor_data[only_vendor_data["event_timestamp"].between(li_data.loc[case, :]["start_timestamp"], li_data.loc[case, :]["end_timestamp"])]
#     avg_daily_workload = between_dates.groupby("event_date").nunique()["case_id"].mean()
#     all_workload.append(avg_daily_workload)

# %% [raw]
# pd.concat([pd.Series(li_data.index), pd.Series(all_workload).rename("avg_vendor_workload")], axis=1).to_csv(case_avg_vendor_workload, index=False)

# %%
case_avg_vendor_workload = pd.read_csv("throughput_dataset/case_avg_vendor_workload.csv").set_index("case_id")

# %%
li_data = pd.merge(li_data, case_avg_vendor_workload, how="left", left_index=True, right_index=True)

# %% [markdown]
# Finished line item level case dataset:

# %%
li_data = li_data.reset_index()

# %%
li_data.head()
# Out:
#             case_id           start_timestamp  event_value_EUR    case_vendor  \
# 0  4507000266_00010 2018-02-01 08:53:00+00:00            134.0  vendorID_0103
# 1  4507000268_00010 2018-02-01 08:56:00+00:00            212.0  vendorID_0105
# 2  4507000268_00020 2018-02-01 08:56:00+00:00            389.0  vendorID_0105
# 3  4507000272_00010 2018-02-01 09:06:00+00:00            266.0  vendorID_0137
# 4  4507000272_00040 2018-02-01 09:06:00+00:00           1272.0  vendorID_0137
#
#   case_PR_NPR case_product_type case_product_specific  \
# 0          PR         Packaging                Labels
# 1          PR         Packaging                Labels
# 2          PR         Packaging                Labels
# 3         NPR             Sales   Products for Resale
# 4         NPR             Sales   Products for Resale
#
#               end_timestamp        throughput  rework_activities  \
# 0 2018-04-26 09:14:00+00:00  84 days 00:21:00                0.0
# 1 2018-09-05 12:10:00+00:00 216 days 03:14:00                0.0
# 2 2018-09-05 12:10:00+00:00 216 days 03:14:00                0.0
# 3 2018-09-05 12:12:00+00:00 216 days 03:06:00                0.0
# 4 2018-09-05 12:12:00+00:00 216 days 03:06:00                0.0
#
#    payment_block  automation  avg_vendor_workload
# 0          False         0.0            49.272727
# 1          False         0.0            13.402778
# 2          False         0.0            13.402778
# 3          False        25.0             3.647059
# 4          False        25.0             3.647059

# %% [markdown]
# ## Creating a table of case attributes for each purchase order

# %% [markdown]
# Many of the attributes in the line item dataset are taken from the purchase order level, and thus duplicated across multiple observations.
# It therefore may be viable to group cases by the purchase order instead of line item.

# %% [markdown]
# Are all of the line items in one purchase always cleared ("clear invoice") on the same day? The majority yes (6961) but 6.5% are not (486).

# %%
pd.DataFrame(data.groupby("case_PO_id").apply(lambda group: group[group["event_name"]=="Clear Invoice"])["event_timestamp"]).reset_index().groupby("case_PO_id").nunique()["event_timestamp"].value_counts()
# Out:
# 1    6961
# 2     418
# 3      55
# 4      11
# 7       1
# 5       1
# Name: event_timestamp, dtype: int64

# %% [markdown]
# Within one purchase order document, there is on average 3.5 different line items.
#
# Attributes that are the same for every line item in each purchase order:
# * vendor
# * PR_NPR
# * product type
# * specific product type
# * The process (trace) followed seems to be the same for every line item in one purchase order, with the same resources working on each of the items.
#
# Attributes that differ for every line item in each purchase order, and will need to be averaged:
# * line item values
#
# Attributes that will need to be calculated from one of the line items in the purchase order:
# * automation rate
# * rework rate
# * payment block occurred
#
# Attributes that only exist at the purchase order level:
# * number of line items in one purchase order

# %%
data.groupby("case_PO_id").nunique().mean()
# Out:
# case_id                   3.474822
# event_id                 19.641869
# event_name                5.707265
# event_timestamp           7.268967
# event_resource            5.732241
# event_value_EUR           3.113737
# case_vendor               1.000000
# case_PR_NPR               0.997449
# case_product_type         1.007923
# case_product_specific     1.035853
# automation                1.283201
# event_date                5.422452
# dtype: float64

# %% [markdown]
# Creating a case attributes dataframe, from the purchase order level:
#
# Because the cases within a purchase order tend to follow the same process, be worked on by the same resources, etc, one line item case is used as the "representative" of the line items in a purchase order.

# %%
li_data["case_PO_id"] = li_data["case_id"].str.split("_", expand=True)[0]

# %%
PO_data = li_data.groupby("case_PO_id").nth(0).reset_index()

# %%
PO_data.head()
# Out:
#    case_PO_id           case_id           start_timestamp  event_value_EUR  \
# 0  4507000266  4507000266_00010 2018-02-01 08:53:00+00:00            134.0
# 1  4507000268  4507000268_00010 2018-02-01 08:56:00+00:00            212.0
# 2  4507000272  4507000272_00010 2018-02-01 09:06:00+00:00            266.0
# 3  4507000273  4507000273_00010 2018-02-01 09:25:00+00:00            528.0
# 4  4507000287  4507000287_00010 2018-02-01 10:17:00+00:00            583.0
#
#      case_vendor case_PR_NPR case_product_type case_product_specific  \
# 0  vendorID_0103          PR         Packaging                Labels
# 1  vendorID_0105          PR         Packaging                Labels
# 2  vendorID_0137         NPR             Sales   Products for Resale
# 3  vendorID_0138         NPR             Sales   Products for Resale
# 4  vendorID_0148         NPR             Sales   Products for Resale
#
#               end_timestamp        throughput  rework_activities  \
# 0 2018-04-26 09:14:00+00:00  84 days 00:21:00                0.0
# 1 2018-09-05 12:10:00+00:00 216 days 03:14:00                0.0
# 2 2018-09-05 12:12:00+00:00 216 days 03:06:00                0.0
# 3 2018-08-03 11:21:00+00:00 183 days 01:56:00                0.0
# 4 2018-08-02 12:43:00+00:00 182 days 02:26:00                0.0
#
#    payment_block  automation  avg_vendor_workload
# 0          False         0.0            49.272727
# 1          False         0.0            13.402778
# 2          False        25.0             3.647059
# 3           True         0.0             9.121951
# 4           True         0.0             3.714286

# %% [markdown]
# ### Feature engineering purchase order level case attributes

# %%
PO_data = PO_data.set_index("case_PO_id")

# %% [markdown]
# Number of line items in each purchase order:

# %%
num_items = data.groupby("case_PO_id").nunique()["case_id"].rename("num_items")
num_items.index = num_items.index.astype("str")

# %%
PO_data = pd.merge(PO_data, num_items, how="left", left_index=True, right_index=True)

# %% [markdown]
# Average line item value in each purchase order:

# %%
avg_value = data.groupby("case_PO_id").apply(lambda group: group[group["event_name"]=="Create Purchase Order Item"])["event_value_EUR"].reset_index().groupby("case_PO_id").mean()["event_value_EUR"]
avg_value.index = avg_value.index.astype("str")

# %%
PO_data["event_value_EUR"] = avg_value
PO_data = PO_data.rename(columns={"event_value_EUR":"avg_value_EUR"})

# %% [markdown]
# Final purchase order level dataset:

# %%
PO_data = PO_data.reset_index()

# %%
PO_data.head()
# Out:
#    case_PO_id           case_id           start_timestamp  avg_value_EUR  \
# 0  4507000266  4507000266_00010 2018-02-01 08:53:00+00:00          134.0
# 1  4507000268  4507000268_00010 2018-02-01 08:56:00+00:00          300.5
# 2  4507000272  4507000272_00010 2018-02-01 09:06:00+00:00          769.0
# 3  4507000273  4507000273_00010 2018-02-01 09:25:00+00:00          598.5
# 4  4507000287  4507000287_00010 2018-02-01 10:17:00+00:00          581.5
#
#      case_vendor case_PR_NPR case_product_type case_product_specific  \
# 0  vendorID_0103          PR         Packaging                Labels
# 1  vendorID_0105          PR         Packaging                Labels
# 2  vendorID_0137         NPR             Sales   Products for Resale
# 3  vendorID_0138         NPR             Sales   Products for Resale
# 4  vendorID_0148         NPR             Sales   Products for Resale
#
#               end_timestamp        throughput  rework_activities  \
# 0 2018-04-26 09:14:00+00:00  84 days 00:21:00                0.0
# 1 2018-09-05 12:10:00+00:00 216 days 03:14:00                0.0
# 2 2018-09-05 12:12:00+00:00 216 days 03:06:00                0.0
# 3 2018-08-03 11:21:00+00:00 183 days 01:56:00                0.0
# 4 2018-08-02 12:43:00+00:00 182 days 02:26:00                0.0
#
#    payment_block  automation  avg_vendor_workload  num_items
# 0          False         0.0            49.272727          1
# 1          False         0.0            13.402778          2
# 2          False        25.0             3.647059          2
# 3           True         0.0             9.121951          2
# 4           True         0.0             3.714286          2

# %% [raw]
# li_data.to_csv("throughput_dataset/line_item_dataset.csv", index=False)

# %% [raw]
# PO_data.to_csv("throughput_dataset/PO_dataset.csv", index=False)

# %% [markdown]
# ## Pre-processing for modelling

# %% [markdown]
# For the later modelling, having too many one-hot encoded features created from the factor levels could cause dimensionality problems.
# Factor level aggregation is explored in the notebook "Exploring the Processed Dataset", and implemented here.
#
# The datasets also need to be formatted so that they can be processed by an algorithm: e.g. dropping non-numerical id columns, etc.

# %%
li_X = li_data[["event_value_EUR", "case_vendor", "case_PR_NPR", "case_product_type", "case_product_specific", "rework_activities", "payment_block", "automation", "avg_vendor_workload"]]
li_y = li_data["throughput"]

# %%
PO_X = PO_data[["avg_value_EUR", "case_vendor", "case_PR_NPR", "case_product_type", "case_product_specific", "rework_activities", "payment_block", "automation", "avg_vendor_workload", "num_items"]]          
PO_y = PO_data["throughput"]

# %%
li_y = li_y.dt.days
PO_y = PO_y.dt.days

# %% [markdown]
# "other" levels always start with _ so that it becomes the reference group in the models.

# %%
# PR/NPR
li_X = li_X.replace({"case_PR_NPR" : {"NPR":"_NPR", "OTHER":"_NPR"}})

# %%
# group product types
product_types = {key: "_other_product_type" for key in li_data["case_product_type"].unique()}
product_types["Packaging"] = "Packaging"
product_types["Sales"] = "Sales"
product_types["Additives"] = "Additives"
li_X = li_X.replace({"case_product_type" : product_types})

# %%
# specific product types
specific_types = {key: "_other_specific_type" for key in li_data["case_product_specific"].unique()}
specific_types["Products for Resale"] = "Products for Resale"
specific_types["Labels"] = "Labels"
specific_types["Metal Containers & Lids < 30L"] = "Containers"
specific_types["Plastic Containers & Lids < 30L"] = "Containers"
specific_types["Extenders"] = "Extenders"
li_X = li_X.replace({"case_product_specific" : specific_types})

# %%
# vendors
vendors = {key: "_other_vendor" for key in li_data["case_vendor"].unique()}
vendors["vendorID_0120"] = "vendorID_0120"
vendors["vendorID_0104"] = "vendorID_0104"
vendors["vendorID_0171"] = "vendorID_0171"
vendors["vendorID_0136"] = "vendorID_0136"
vendors["vendorID_0106"] = "vendorID_0106"
li_X = li_X.replace({"case_vendor" : vendors})

# %%
li_X = li_X.replace({"payment_block" : {True:1, False:0}})

# %%
li_X
# Out:
#        event_value_EUR    case_vendor case_PR_NPR case_product_type  \
# 0                134.0  _other_vendor          PR         Packaging
# 1                212.0  _other_vendor          PR         Packaging
# 2                389.0  _other_vendor          PR         Packaging
# 3                266.0  _other_vendor        _NPR             Sales
# 4               1272.0  _other_vendor        _NPR             Sales
# ...                ...            ...         ...               ...
# 25631            142.0  _other_vendor        _NPR             Sales
# 25632             44.0  _other_vendor        _NPR             Sales
# 25633             14.0  _other_vendor        _NPR             Sales
# 25634             27.0  _other_vendor        _NPR             Sales
# 25635            162.0  vendorID_0136          PR         Packaging
#
#       case_product_specific  rework_activities  payment_block  automation  \
# 0                    Labels                0.0              0         0.0
# 1                    Labels                0.0              0         0.0
# 2                    Labels                0.0              0         0.0
# 3       Products for Resale                0.0              0        25.0
# 4       Products for Resale                0.0              0        25.0
# ...                     ...                ...            ...         ...
# 25631   Products for Resale                0.0              1        20.0
# 25632   Products for Resale                0.0              1        20.0
# 25633   Products for Resale                0.0              1        20.0
# 25634   Products for Resale                0.0              1        20.0
# 25635                Labels                0.0              1         0.0
#
#        avg_vendor_workload
# 0                49.272727
# 1                13.402778
# 2                13.402778
# 3                 3.647059
# 4                 3.647059
# ...                    ...
# 25631            14.726027
# 25632            14.726027
# 25633            14.726027
# 25634            14.726027
# 25635            28.913043
#
# [25636 rows x 9 columns]

# %%
# PR/NPR
PO_X = PO_X.replace({"case_PR_NPR" : {"NPR":"_NPR", "OTHER":"_NPR"}})

# %%
# group product types
product_types = {key: "_other_product_type" for key in PO_data["case_product_type"].unique()}
product_types["Packaging"] = "Packaging"
product_types["Sales"] = "Sales"
product_types["Additives"] = "Additives"
PO_X = PO_X.replace({"case_product_type" : product_types})

# %%
# specific product types
specific_types = {key: "_other_specific_type" for key in PO_data["case_product_specific"].unique()}
specific_types["Products for Resale"] = "Products for Resale"
specific_types["Labels"] = "Labels"
specific_types["Metal Containers & Lids < 30L"] = "Containers"
specific_types["Plastic Containers & Lids < 30L"] = "Containers"
specific_types["Extenders"] = "Extenders"
PO_X = PO_X.replace({"case_product_specific" : specific_types})

# %%
# vendors
vendors = {key: "_other_vendor" for key in PO_data["case_vendor"].unique()}
vendors["vendorID_0120"] = "vendorID_0120"
vendors["vendorID_0104"] = "vendorID_0104"
vendors["vendorID_0171"] = "vendorID_0171"
vendors["vendorID_0136"] = "vendorID_0136"
vendors["vendorID_0106"] = "vendorID_0106"
PO_X = PO_X.replace({"case_vendor" : vendors})

# %%
PO_X = PO_X.replace({"payment_block" : {True:1, False:0}})

# %% [markdown]
# Comparing the full versus new modelling dataset:

# %%
PO_model_data = pd.concat([PO_X, PO_y], axis=1)
li_model_data = pd.concat([li_X, li_y], axis=1)

# %%
PO_data
# Out:
#       case_PO_id           case_id           start_timestamp  avg_value_EUR  \
# 0     4507000266  4507000266_00010 2018-02-01 08:53:00+00:00     134.000000
# 1     4507000268  4507000268_00010 2018-02-01 08:56:00+00:00     300.500000
# 2     4507000272  4507000272_00010 2018-02-01 09:06:00+00:00     769.000000
# 3     4507000273  4507000273_00010 2018-02-01 09:25:00+00:00     598.500000
# 4     4507000287  4507000287_00010 2018-02-01 10:17:00+00:00     581.500000
# ...          ...               ...                       ...            ...
# 7318  4508046815  4508046815_00010 2018-02-08 06:33:00+00:00    3556.777778
# 7319  4508046831  4508046831_00010 2018-02-08 07:18:00+00:00    1053.666667
# 7320  4508046840  4508046840_00010 2018-02-08 07:42:00+00:00     201.666667
# 7321  4508047026  4508047026_00010 2018-03-08 06:39:00+00:00     157.714286
# 7322  4508047525  4508047525_00010 2018-06-08 12:02:00+00:00     162.000000
#
#         case_vendor case_PR_NPR case_product_type  \
# 0     vendorID_0103          PR         Packaging
# 1     vendorID_0105          PR         Packaging
# 2     vendorID_0137         NPR             Sales
# 3     vendorID_0138         NPR             Sales
# 4     vendorID_0148         NPR             Sales
# ...             ...         ...               ...
# 7318  vendorID_0122         NPR      CAPEX & SOCS
# 7319  vendorID_0382         NPR             Sales
# 7320  vendorID_0477         NPR             Sales
# 7321  vendorID_0114         NPR             Sales
# 7322  vendorID_0136          PR         Packaging
#
#                case_product_specific             end_timestamp  \
# 0                             Labels 2018-04-26 09:14:00+00:00
# 1                             Labels 2018-09-05 12:10:00+00:00
# 2                Products for Resale 2018-09-05 12:12:00+00:00
# 3                Products for Resale 2018-08-03 11:21:00+00:00
# 4                Products for Resale 2018-08-02 12:43:00+00:00
# ...                              ...                       ...
# 7318  Laboratory Supplies & Services 2018-08-23 11:39:00+00:00
# 7319             Products for Resale 2018-08-23 11:40:00+00:00
# 7320             Products for Resale 2018-08-23 11:39:00+00:00
# 7321             Products for Resale 2018-08-23 11:39:00+00:00
# 7322                          Labels 2018-08-23 15:58:00+00:00
#
#             throughput  rework_activities  payment_block  automation  \
# 0     84 days 00:21:00                0.0          False         0.0
# 1    216 days 03:14:00                0.0          False         0.0
# 2    216 days 03:06:00                0.0          False        25.0
# 3    183 days 01:56:00                0.0           True         0.0
# 4    182 days 02:26:00                0.0           True         0.0
# ...                ...                ...            ...         ...
# 7318 196 days 05:06:00                0.0          False         0.0
# 7319 196 days 04:22:00                0.0           True        20.0
# 7320 196 days 03:57:00                0.0           True        20.0
# 7321 168 days 05:00:00                0.0           True        20.0
# 7322  76 days 03:56:00                0.0           True         0.0
#
#       avg_vendor_workload  num_items
# 0               49.272727          1
# 1               13.402778          2
# 2                3.647059          2
# 3                9.121951          2
# 4                3.714286          2
# ...                   ...        ...
# 7318            18.709302          9
# 7319            27.800000          3
# 7320             2.083333          3
# 7321            14.726027          7
# 7322            28.913043          1
#
# [7323 rows x 15 columns]

# %%
PO_model_data
# Out:
#       avg_value_EUR    case_vendor case_PR_NPR    case_product_type  \
# 0        134.000000  _other_vendor          PR            Packaging
# 1        300.500000  _other_vendor          PR            Packaging
# 2        769.000000  _other_vendor        _NPR                Sales
# 3        598.500000  _other_vendor        _NPR                Sales
# 4        581.500000  _other_vendor        _NPR                Sales
# ...             ...            ...         ...                  ...
# 7318    3556.777778  _other_vendor        _NPR  _other_product_type
# 7319    1053.666667  _other_vendor        _NPR                Sales
# 7320     201.666667  _other_vendor        _NPR                Sales
# 7321     157.714286  _other_vendor        _NPR                Sales
# 7322     162.000000  vendorID_0136          PR            Packaging
#
#      case_product_specific  rework_activities  payment_block  automation  \
# 0                   Labels                0.0              0         0.0
# 1                   Labels                0.0              0         0.0
# 2      Products for Resale                0.0              0        25.0
# 3      Products for Resale                0.0              1         0.0
# 4      Products for Resale                0.0              1         0.0
# ...                    ...                ...            ...         ...
# 7318  _other_specific_type                0.0              0         0.0
# 7319   Products for Resale                0.0              1        20.0
# 7320   Products for Resale                0.0              1        20.0
# 7321   Products for Resale                0.0              1        20.0
# 7322                Labels                0.0              1         0.0
#
#       avg_vendor_workload  num_items  throughput
# 0               49.272727          1          84
# 1               13.402778          2         216
# 2                3.647059          2         216
# 3                9.121951          2         183
# 4                3.714286          2         182
# ...                   ...        ...         ...
# 7318            18.709302          9         196
# 7319            27.800000          3         196
# 7320             2.083333          3         196
# 7321            14.726027          7         168
# 7322            28.913043          1          76
#
# [7323 rows x 11 columns]

# %% [raw]
# PO_model_data.to_csv("throughput_dataset/PO_modelling_dataset.csv", index=False)
# li_model_data.to_csv("throughput_dataset/line_item_modelling_dataset.csv", index=False)
